# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshuman776/Deep-Learning-Projects-/blob/main/Image_Augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import random
from skimage import exposure
from skimage.util import random_noise
from skimage import transform
from cv2 import resize

# %%
img = mpimg.imread('/content/cat.avif')

# %%
plt.imshow(img)

# %% [markdown]
# **# Rescaling**

# %%
img_rescale = resize(img, (150,150))
plt.imshow(img_rescale)

# %% [markdown]
# this image is blurry image as we can see from previous image

# %%
img_rescale = resize(img, (50,50))
plt.imshow(img_rescale)

# %% [markdown]
# **# Flipping**

# %%
horizontal_flip = np.fliplr(img)
plt.imshow(horizontal_flip)

# %%
Vertical_flip = np.flipud(img)
plt.imshow(Vertical_flip)

# %% [markdown]
# **# Rotation**

# %%
from skimage import transform
tran_img = transform.rotate(img,random.uniform(-40,40))
plt.imshow(tran_img)

# %% [markdown]
# **# Adding Noise**

# %%
img_noise = random_noise(img , mode ='s&p',clip = True)
plt.imshow(img_noise)
